# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %% [markdown]
# Перечень полок, на которых находятся документы хранится в следующем виде:

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

# %% [markdown]
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# - p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# - s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# *Правильно обработайте ситуации, когда пользователь будет вводить несуществующий документ*.
# - l – list – команда, которая выведет список всех документов в формате
# **passport "2207 876234" "Василий Гупкин"**
# - as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень. *Предусмотрите случай, когда пользователь добавляет полку, которая уже существует*.
# - d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. *Предусмотрите сценарий, когда пользователь вводит несуществующий документ*;
# - m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. *Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку*;
# - a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться. *Корректно обработайте ситуацию, когда пользователь будет пытаться добавить документ на несуществующую полку*.

# %%
##########################################################################################
####################################### Блок данных ######################################
##########################################################################################

documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'},
    {'type': 'insurance', 'number': '100', 'name': 'Gena Bubkin'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': [],
    '4': ['100']
}

##########################################################################################
################################### Базовые переменные ###################################
##########################################################################################

full = ('p – поиск человека по номеру документа\ns – поиск номера полки по номеру документа\nl – вывод всех документов в каталоге\nas – добавление новой полки\nd – удаление документа по его номеру\nm – перемещение документа на другую полку\na – добавление нового документа в каталог')
err = ('Данные не найдены')
suc = ('Операция успешно выполнена')
doc_ex = ('Такой предмет уже существует')
obj_not_ex = ('Такого объекта не существует')
shf_not_ex = ('Такой полки не существует')

##########################################################################################
############################ Поиск ФИО по номеру документа ###############################
##########################################################################################

def people(doc_number):
    for doc_num in documents:
        if doc_num['number'] == doc_number:
            result = doc_num['name']
            return result
        else:
            print(doc_ex)
    
##########################################################################################
######################### Поиск номера полки по номеру документа #########################
##########################################################################################
def shelf(doc_number):
#Через цикл "for" перебор пары ключ-значение из списка предметов в словаре
    for key, values in directories.items():
        for i in values:
            if doc_number == i:
                result = key
                return result
    return err

##########################################################################################
################################ Вывод всех документов ###################################
##########################################################################################

def list_all(documents): 
    for i in documents: 
        result = print(i['type'], i['number'], i['name'])       

##########################################################################################
################################### Добавление полки #####################################
##########################################################################################

def add_shelf(doc_number):
    if doc_number not in directories:
        result = directories[doc_number] = []
        print(suc)
        return result
    else:
        print(doc_ex)

##########################################################################################
################################## Удаление документа ####################################
##########################################################################################

# Удаляет номер документа
def del_doc(doc_number):
    for doc_num in documents:
        if doc_num['number'] == doc_number:
            result = documents.remove(doc_num)
            print(suc)
            return result
    print(err)
    return err

# Удаляет полку документа
def del_shelf(doc_number):
    for key, values in directories.items():
        for i in values:
            if doc_number == i:
                result = values.remove(i)
                return result
    return err

# Удаяление номера документа и полки
def delete(doc_number):
    del_doc(doc_number)
    del_shelf(doc_number)

##########################################################################################
################################ Перемещение документа ###################################
##########################################################################################

def move():
    shelf_num = input('Введите номер полки на которую требуется переместить документ: ')
    doc_number = input('Введите номер перемещаемого документа: ')
    if shelf_num not in directories:
        print(shf_not_ex)
    else:
        for doc_num in documents:
            if doc_num['number'] != doc_number:
                print(obj_not_ex)
                break
            elif doc_num['number'] == doc_number:
                for key, values in directories.items():
                    for i in values:
                        if doc_number == i:
                            values.remove(i)
                            directories[shelf_num].append(doc_number)
        return err

##########################################################################################
################################ Добавление документа ####################################
##########################################################################################

def add_doc():
    doc_number = input('Введите номер нового документа: ')
    doc_type = input('Введите введите тип документа: ')
    doc_name = input('Введите имя владельца документа: ')
    shelf_num = input('Введите номер полки на которую требуется поместить документ: ')
    if len(doc_number) < 1:
        print('Номер документа не может быть пустым!')
    elif shelf_num not in directories:
        print(shf_not_ex)
    else:
        if doc_number not in documents[1][0]:
            for values in directories:
                    if doc_number != values:
                        directories[shelf_num].append(doc_number)
                        documents.append({"type":doc_type, "number":doc_number,"name":doc_name})
                        break
    
##########################################################################################
############################ Блок пользовательского ввода ################################
##########################################################################################

action = input('Пожалуйста введите команду, вывести список всех команд - введите "full" ')

if action == 'full':
    print(full)
elif action == 'p':
    print(people(input('Введите номер документа: ')))
elif action == 's':
    print(shelf(input('Введите номер документа: ')))
elif action == 'l':
    list_all(documents)
elif action == 'as':
    add_shelf(input('Введте номер полки: '))
elif action == 'd':
    delete(input('Введите номер документа для удаления: '))
elif action == 'm':
    move()
elif action == 'a':
    add_doc()
elif action == 'bb':
    del_doc(input('Введите номер документа для удаления: '))
elif action == 'cc':
    del_shelf(input('Введите номер документа для удаления: '))
elif action == 'dd':
    check(input('Введите номер документа для удаления: '))
else: print('Неверная команда, список всех команд доступен через команду "full "')

print(documents)
print(directories)
# Out:
# Пожалуйста введите команду, вывести список всех команд - введите "full" a
# Введите номер нового документа: 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
def cylinder():
    r = float(input())
    h = float(input())
    # площадь боковой поверхности цилиндра:
    side = 2 * 3.14 * r * h
    # площадь одного основания цилиндра:
    circle = 3.14 * r**2
    # полная площадь цилиндра:
    full = side + 2 * circle
    return full
 
square = cylinder()
print(square)
# Out:
# 99
# 99
# 123100.56

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
